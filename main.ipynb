# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_dds = pd.read_csv('diabetes.csv')
print(f"Total row and column: {df_dds.shape}")
# Out:
# Total row and column: (768, 9)

# %%
print(f'columns in datasets : {df_dds.columns}')
# Out:
# columns in datasets : Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
print(f'Describe of datasets :{df_dds.describe()}')
# Out:
# Describe of datasets :       Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df_dds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df_dds.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df_dds.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df_dds.Age.plot(color="Orange",kind="hist")
plt.show()

# %%
df_dds.Glucose.plot(kind = "hist")
plt.show()

# %%
df_dds.Insulin.plot(color="Red",kind="hist")
plt.show()

# %%
df_dds.SkinThickness.plot(color="Purple",kind = "hist")
plt.show()

# %%
df_dds.Glucose.plot(color="green",kind="bar")
plt.xlabel("Glucose")
plt.ylabel("frequency")
plt.title("Glucose Bar plot")
plt.show()

# %%
df_dds.Insulin.plot(color="green",kind="bar")
plt.xlabel("Insulin")
plt.ylabel("frequency")
plt.title("Insulin Bar plot")
plt.show()

# %%
df_dds.Age.plot(color="green",kind="bar")
plt.xlabel("Age")
plt.ylabel("frequency")
plt.title("Age Bar plot")
plt.show()

# %%
sns.countplot(data = df_dds["Pregnancies"],palette="viridis")
plt.show()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_16064\3411844698.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df_dds["Pregnancies"],palette="viridis")

# %%
df_dds.Pregnancies.value_counts()
# Out:
# Pregnancies
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 17      1
# 15      1
# Name: count, dtype: int64

# %%
sizes = df_dds.Pregnancies.value_counts().values
labels = df_dds.Pregnancies.value_counts().index
colors = ["green","pink","yellow","purple","grey","red","blue","darkblue","cyan","white","black"]
plt.pie(sizes,data=df_dds,labels=labels,colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x23660c33380>,
# ...
#  [Text(0.9364907030107017, 0.5770486662098109, '1'),
#   Text(0.013498682312974538, 1.0999171721433454, '0'),
#   Text(-0.8358617555631915, 0.7150770067529928, '2'),
#   Text(-1.0997699277236774, -0.022496801431702015, '3'),
#   Text(-0.9044951551840918, -0.6260099953263571, '4'),
#   Text(-0.48247770934589396, -0.988541986960766, '5'),
#   Text(-0.017997593073547435, -1.0998527568013636, '6'),
#   Text(0.40007966204566814, -1.0246639761489735, '7'),
#   Text(0.7184902297005191, -0.8329296427819672, '8'),
#   Text(0.9146165337706407, -0.6111273158298348, '9'),
#   Text(1.02301903509328, -0.4042673049317922, '10'),
#   Text(1.0702339450050877, -0.2541639293032102, '11'),
#   Text(1.0880941987421706, -0.16140326720247566, '13'),
#   Text(1.0973413503617653, -0.0764327206516792, '12'),
#   Text(1.0996687034069363, -0.02699523564090196, '14'),
#   Text(1.0999171739134743, -0.013498538076248979, '17'),
# ...

# %%
df_dds.hist(bins=50, figsize=(20,15))
plt.show()

# %%
corr_matrix = df_dds.corr()*100
corr_matrix['Outcome'].sort_values(ascending=False)
# Out:
# Outcome                     100.000000
# Glucose                      46.658140
# BMI                          29.269466
# Age                          23.835598
# Pregnancies                  22.189815
# DiabetesPedigreeFunction     17.384407
# Insulin                      13.054795
# SkinThickness                 7.475223
# BloodPressure                 6.506836
# Name: Outcome, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score


x = df_dds[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 
        'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']]
y = df_dds['Outcome']


x = x.dropna()
y = y.loc[x.index]


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Model
model = DecisionTreeClassifier(random_state=42)
model.fit(x_train, y_train)


y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy:", accuracy*100)
# Out:
# Model Accuracy: 74.67532467532467

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

x = df_dds[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 
            'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']]
y = df_dds['Outcome']

x = x.dropna()
y = y.loc[x.index]

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

x_train, x_test, y_train, y_test = train_test_split(
    x_scaled, y, test_size=0.2, random_state=42
)

model = LogisticRegression(random_state=42, max_iter=1000)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy:", accuracy*100)
# Out:
# Model Accuracy: 75.32467532467533

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

x = df_dds[['Age', 'BloodPressure', 'DiabetesPedigreeFunction']]
y = df_dds['Outcome']

x = x.dropna()
y = y.loc[x.index]

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

model = DecisionTreeClassifier(max_depth=4, random_state=42)
model.fit(x_train, y_train)

print("Model trained. Accuracy:", model.score(x_test, y_test) * 100)
# Out:
# Model trained. Accuracy: 61.68831168831169

# %%
import gradio as gr

def predict_diabetes(age, bp, dpf):
    
    user_data = np.array([[age, bp, dpf]])
    
    prediction = model.predict(user_data)[0]
    
    if prediction == 1:
        result = "The model predicts: Diabetes"
    else:
        result = "The model predicts: No Diabetes"
    
    return result
    
with gr.Blocks() as demo:
    gr.Markdown("*Diabetes Prediction App (CODE BY RAHUL)*")
    
    age_input = gr.Number(label="Age")
    bp_input = gr.Number(label="Blood Pressure")
    dpf_input = gr.Number(label="Diabetes Pedigree Function")

    predict_btn = gr.Button("Predict")
    
    output_box = gr.Textbox(label="Prediction Result")
    
    predict_btn.click(fn=predict_diabetes, 
                      inputs=[age_input, bp_input, dpf_input], 
                      outputs=output_box)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
